# %%
#Read the three files into python as dataframes
import pandas as pd
import numpy as np

file1 = pd.read_csv('/Users/ayeesha/IH-Labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv')
file2 = pd.read_csv('/Users/ayeesha/IH-Labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')
file3 = pd.read_csv('/Users/ayeesha/IH-Labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')
display(file1.shape)
display(file2.shape)
display(file3.shape)




cols = []
for column in file1.columns:
    cols.append(column.lower())
file1.columns = cols



file1.rename(columns = {'st':'state'}, inplace = True)

display(file1.head())
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)
#   customer       state gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
# ...

# %%
#isna.sum()
#
file1.isnull().sum()
#file2.isnull().sum() # gender 5 customer lifetime value      4
#file3.isnull().sum()
# Out:
# customer                     2937
# state                        2937
# gender                       3054
# education                    2937
# customer lifetime value      2940
# income                       2937
# monthly premium auto         2937
# number of open complaints    2937
# policy type                  2937
# vehicle class                2937
# total claim amount           2937
# dtype: int64

# %%
cols = []
for column in file2.columns:
    cols.append(column.lower())
file2.columns = cols



file2.rename(columns = {'st':'state'}, inplace = True)

display(file2.head())
# Out:
#   customer       state gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints  total claim amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy type  vehicle class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
cols = []
for column in file3.columns:
    cols.append(column.lower())
file3.columns = cols



display(file3.head())
# Out:
#   customer       state  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total claim amount  vehicle class
# ...

# %%
dataframe = pd.concat([file1, file2,file3], axis=0) #discuss axis here
dataframe.shape
dataframe
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
dataframe = dataframe[['customer', 'state', 'gender', 'education', 'income', 
        'monthly premium auto', 'policy type','customer lifetime value','number of open complaints',
        'vehicle class', 'total claim amount']]
display(dataframe)


# file2 = file2[['customer', 'state', 'gender', 'education', 'income', 
#         'monthly premium auto', 'policy type','customer lifetime value','number of open complaints',
#         'vehicle class', 'total claim amount']]
# display(file2)
# file3 = file3[['customer', 'state', 'gender', 'education', 'income', 
#         'monthly premium auto', 'policy type','customer lifetime value','number of open complaints',
#         'vehicle class', 'total claim amount']]
# display(file3)
# Out:
#      customer       state gender             education   income  \
# 0     RB50392  Washington    NaN                Master      0.0
# 1     QZ44356     Arizona      F              Bachelor      0.0
# 2     AI49188      Nevada      F              Bachelor  48767.0
# 3     WW63253  California      M              Bachelor      0.0
# 4     GA49547  Washington      M  High School or Below  36357.0
# ...       ...         ...    ...                   ...      ...
# 7065  LA72316  California      M              Bachelor  71941.0
# 7066  PK87824  California      F               College  21604.0
# 7067  TD14365  California      M              Bachelor      0.0
# 7068  UP19263  California      M               College  21941.0
# 7069  Y167826  California      M               College      0.0
#
#       monthly premium auto     policy type customer lifetime value  \
# 0                   1000.0   Personal Auto                     NaN
# ...

# %%
dataframe.drop(['education','number of open complaints'], axis=1, inplace=True)
display(dataframe)
# Out:
#      customer       state gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
dataframe.isna().sum()
# Out:
# customer                   2937
# state                      2937
# gender                     3059
# customer lifetime value    2944
# income                     2937
# monthly premium auto       2937
# policy type                2937
# vehicle class              2937
# total claim amount         2937
# dtype: int64

# %%
dataframe.dtypes
# dataframe
# result = dataframe.dtypes
# print(result)
# Out:
# customer                    object
# state                       object
# gender                      object
# income                     float64
# monthly premium auto       float64
# policy type                 object
# customer lifetime value     object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
# dataframe["customer lifetime value"].str.replace("%","")
# display(dataframe)


dataframe['customer lifetime value'] = dataframe['customer lifetime value'].str.replace('%','')

display(dataframe)
# Out:
#      customer       state gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F               697953.59      0.0
# 2     AI49188      Nevada      F              1288743.17  48767.0
# 3     WW63253  California      M               764586.18      0.0
# 4     GA49547  Washington      M               536307.65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                     NaN  71941.0
# 7066  PK87824  California      F                     NaN  21604.0
# 7067  TD14365  California      M                     NaN      0.0
# 7068  UP19263  California      M                     NaN  21941.0
# 7069  Y167826  California      M                     NaN      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
dataframe['customer lifetime value'] = dataframe['customer lifetime value'].astype(float)
dataframe.dtypes
# Out:
# customer                    object
# state                       object
# gender                      object
# customer lifetime value    float64
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
dataframe.isna().sum()
# Out:
# customer                   2937
# state                      2937
# gender                     3059
# income                     2937
# monthly premium auto       2937
# policy type                2937
# customer lifetime value    2944
# vehicle class              2937
# total claim amount         2937
# dtype: int64

# %%
round(dataframe.isna().sum()/len(dataframe),4)*100 # shows the percentage of null values in a column

nulls_df = pd.DataFrame(round(dataframe.isna().sum()/len(dataframe),4)*100) #creating a new dataset for the nulls
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                header_name  percent_nulls
# 0                 customer          24.32
# 1                    state          24.32
# 2                   gender          25.34
# 3                   income          24.32
# 4     monthly premium auto          24.32
# 5              policy type          24.32
# 6  customer lifetime value          24.38
# 7            vehicle class          24.32
# 8       total claim amount          24.32

# %%
columns_drop = nulls_df[nulls_df['percent_nulls']>25]['header_name']  # dummy case with 3
print(columns_drop.values)
#donors = donors.drop(columns_drop, axis=1)  # drop a list of columns DO NOT RUN THIS
#donors = donors.drop(['gender'], axis=1)  # drop a single column DO NOT RUN THIS
# Out:
# ['gender']

# %%
# Replacing/imputing null values

dataframe[dataframe['customer lifetime value'].isna()==True].head(60) # checking rows that are null based on a specific column
# Out:
#      customer       state gender   income  monthly premium auto  \
# 0     RB50392  Washington    NaN      0.0                1000.0
# 78    SP81997  Washington      F  41275.0                  96.0
# 988   GT62080  Washington      M  55561.0                  63.0
# 1071      NaN         NaN    NaN      NaN                   NaN
# 1072      NaN         NaN    NaN      NaN                   NaN
# 1073      NaN         NaN    NaN      NaN                   NaN
# 1074      NaN         NaN    NaN      NaN                   NaN
# 1075      NaN         NaN    NaN      NaN                   NaN
# 1076      NaN         NaN    NaN      NaN                   NaN
# 1077      NaN         NaN    NaN      NaN                   NaN
# 1078      NaN         NaN    NaN      NaN                   NaN
# 1079      NaN         NaN    NaN      NaN                   NaN
# 1080      NaN         NaN    NaN      NaN                   NaN
# 1081      NaN         NaN    NaN      NaN                   NaN
# ...

# %%
dataframe.drop_duplicates()
dataframe
# Out:
#      customer       state gender   income  monthly premium auto  \
# 0     RB50392  Washington    NaN      0.0                1000.0
# 1     QZ44356     Arizona      F      0.0                  94.0
# 2     AI49188      Nevada      F  48767.0                 108.0
# 3     WW63253  California      M      0.0                 106.0
# 4     GA49547  Washington      M  36357.0                  68.0
# ...       ...         ...    ...      ...                   ...
# 7065  LA72316  California      M  71941.0                  73.0
# 7066  PK87824  California      F  21604.0                  79.0
# 7067  TD14365  California      M      0.0                  85.0
# 7068  UP19263  California      M  21941.0                  96.0
# 7069  Y167826  California      M      0.0                  77.0
#
#          policy type  customer lifetime value  vehicle class  \
# 0      Personal Auto                      NaN  Four-Door Car
# 1      Personal Auto                697953.59  Four-Door Car
# ...

# %%
filtered = dataframe[dataframe['income'] > 0]

filtered
# Out:
#      customer       state gender   income  monthly premium auto  \
# 2     AI49188      Nevada      F  48767.0                 108.0
# 4     GA49547  Washington      M  36357.0                  68.0
# 5     OC83172      Oregon      F  62902.0                  69.0
# 6     XZ87318      Oregon      F  55350.0                  67.0
# 8     DY87989      Oregon      M  14072.0                  71.0
# ...       ...         ...    ...      ...                   ...
# 7063  TF56202  California      M  66367.0                  64.0
# 7064  YM19146  California      F  47761.0                 104.0
# 7065  LA72316  California      M  71941.0                  73.0
# 7066  PK87824  California      F  21604.0                  79.0
# 7068  UP19263  California      M  21941.0                  96.0
#
#          policy type  customer lifetime value  vehicle class  \
# 2      Personal Auto               1288743.17   Two-Door Car
# 4      Personal Auto                536307.65  Four-Door Car
# ...
